# %% [markdown]
# **Imports**

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# **Load Final Dataset**

# %%
df = pd.read_csv("/content/master_with_shocks.csv")

# %%
df[["year", "sector", "prod_shock"]].head()
# Out:
#    year        sector  prod_shock
# 0  2005  Basic metals           0
# 1  2006  Basic metals           0
# 2  2007  Basic metals           0
# 3  2008  Basic metals           1
# 4  2009  Basic metals           0

# %% [markdown]
# **Drop Missing Growth Observations**

# %%
reg_df = df.dropna(subset=[
    "sector_output_growth",
    "output_per_worker_growth",
    "output_per_hour_growth"
])

# %% [markdown]
# **Baseline Regression**

# %% [markdown]
# **Model:**
# **Δys,t​=β⋅Shockt​+εs,t​**

# %%
model1 = smf.ols(
    "sector_output_growth ~ prod_shock",
    data=reg_df
).fit(cov_type="HC1")

model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     sector_output_growth   R-squared:                       0.001
# Model:                              OLS   Adj. R-squared:                 -0.004
# Method:                   Least Squares   F-statistic:                    0.5972
# Date:                  Mon, 12 Jan 2026   Prob (F-statistic):              0.441
# Time:                          13:27:23   Log-Likelihood:                -20.642
# No. Observations:                   207   AIC:                             45.28
# Df Residuals:                       205   BIC:                             51.95
# Df Model:                             1
# Covariance Type:                    HC1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0015      0.021     -0.072      0.943      -0.043       0.040
# prod_shock     0.0216      0.028      0.773      0.440      -0.033       0.076
# ==============================================================================
# Omnibus:                      184.233   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5563.997
# Skew:                          -3.144   Prob(JB):                         0.00
# Kurtosis:                      27.608   Cond. No.                         3.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %% [markdown]
# **Sector Fixed Effects**

# %%
model2 = smf.ols(
    "sector_output_growth ~ prod_shock + C(sector)",
    data=reg_df
).fit(cov_type="HC1")

model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     sector_output_growth   R-squared:                       0.090
# Model:                              OLS   Adj. R-squared:                 -0.042
# Method:                   Least Squares   F-statistic:                    0.7838
# Date:                  Mon, 12 Jan 2026   Prob (F-statistic):              0.764
# Time:                          13:27:26   Log-Likelihood:                -10.986
# No. Observations:                   207   AIC:                             75.97
# Df Residuals:                       180   BIC:                             166.0
# Df Model:                            26
# Covariance Type:                    HC1
# ============================================================================================================================================================================
#                                                                                                                coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                    0.0724      0.024      2.991      0.003       0.025       0.120
# C(sector)[T.Chemicals and chemical products]                                                                -0.1288      0.091     -1.412      0.158      -0.308       0.050
# C(sector)[T.Coke, refined petroleum products and nuclear fuel]                                              -0.0664      0.045     -1.485      0.137      -0.154       0.021
# C(sector)[T.Electrical machinery and apparatus n.e.c.]                                                       0.0494      0.149      0.333      0.739      -0.242       0.341
# C(sector)[T.Electricity]                                                                                    -0.1834      0.166     -1.106      0.269      -0.508       0.142
# C(sector)[T.Fabricated metal products, except machinery and equipment]                                      -0.0473      0.063     -0.751      0.453      -0.171       0.076
# C(sector)[T.Food products and beverages]                                                                    -0.0918      0.084     -1.096      0.273      -0.256       0.072
# C(sector)[T.Furniture manufacturing n.e.c.]                                                                 -0.1068      0.062     -1.728      0.084      -0.228       0.014
# C(sector)[T.General Index]                                                                                  -0.0413      0.044     -0.946      0.344      -0.127       0.044
# C(sector)[T.Luggage, handbags, saddlery, harness and footwear tanning and dressing of leather products]     -0.1130      0.091     -1.236      0.217      -0.292       0.066
# C(sector)[T.Machinery and equipment n.e.c.]                                                                 -0.0009      0.055     -0.016      0.987      -0.109       0.107
# C(sector)[T.Manufacturing]                                                                                  -0.1034      0.106     -0.978      0.328      -0.311       0.104
# C(sector)[T.Medical, precision and optical instruments, watches and clocks]                                 -0.1310      0.094     -1.396      0.163      -0.315       0.053
# C(sector)[T.Mining and Quarrying]                                                                           -0.0664      0.034     -1.964      0.050      -0.133      -0.000
# C(sector)[T.Motor vehicles, trailers and semi-trailers]                                                      0.0085      0.063      0.135      0.893      -0.115       0.132
# C(sector)[T.Office, accounting and computing machinery]                                                     -0.1560      0.073     -2.133      0.033      -0.299      -0.013
# C(sector)[T.Other non-metallic mineral products]                                                            -0.0460      0.039     -1.181      0.237      -0.122       0.030
# C(sector)[T.Other transport equipment]                                                                      -0.0278      0.069     -0.402      0.687      -0.164       0.108
# C(sector)[T.Paper and paper products]                                                                       -0.1413      0.107     -1.318      0.187      -0.351       0.069
# C(sector)[T.Publishing, printing and reproduction of recorded media]                                        -0.0404      0.056     -0.727      0.467      -0.149       0.068
# C(sector)[T.Radio, TV and communication equipment and apparatus]                                             0.1377      0.147      0.937      0.349      -0.150       0.426
# C(sector)[T.Rubber and plastics products]                                                                   -0.2864      0.285     -1.006      0.315      -0.845       0.272
# C(sector)[T.Textiles]                                                                                       -0.1081      0.077     -1.399      0.162      -0.260       0.043
# C(sector)[T.Tobacco products]                                                                               -0.1079      0.051     -2.122      0.034      -0.207      -0.008
# C(sector)[T.Wearing apparel dressing and dyeing of fur]                                                     -0.0408      0.043     -0.945      0.345      -0.125       0.044
# C(sector)[T.Wood and products of wood and cork except furniture articles of straw and plating materials]    -0.0713      0.057     -1.253      0.210      -0.183       0.040
# prod_shock                                                                                                   0.0212      0.030      0.702      0.483      -0.038       0.080
# ==============================================================================
# Omnibus:                      168.194   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3449.457
# Skew:                          -2.885   Prob(JB):                         0.00
# Kurtosis:                      22.148   Cond. No.                         28.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %% [markdown]
# **Time Fixed Effects**

# %%
model3 = smf.ols(
    "sector_output_growth ~ prod_shock + C(sector) + C(year)",
    data=reg_df
).fit(cov_type="HC1")

model3.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 33, but rank is 32
#   warnings.warn('covariance of constraints does not have full '
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     sector_output_growth   R-squared:                       0.551
# Model:                              OLS   Adj. R-squared:                  0.469
# Method:                   Least Squares   F-statistic:                     6.876
# Date:                  Mon, 12 Jan 2026   Prob (F-statistic):           8.42e-18
# Time:                          13:27:31   Log-Likelihood:                 62.211
# No. Observations:                   207   AIC:                            -58.42
# Df Residuals:                       174   BIC:                             51.56
# Df Model:                            32
# Covariance Type:                    HC1
# ============================================================================================================================================================================
#                                                                                                                coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                
# C(year)[T.2009]                                                                                              0.5189      0.089      5.810      0.000       0.344       0.694
# C(year)[T.2010]                                                                                              0.5444      0.088      6.199      0.000       0.372       0.717
# C(year)[T.2011]                                                                                              0.5053      0.090      5.626      0.000       0.329       0.681
# C(year)[T.2012]                                                                                              0.4719      0.088      5.371      0.000       0.300       0.644
# prod_shock                                                                                                   0.2458      0.044      5.566      0.000       0.159       0.332
# ==============================================================================
# Omnibus:                      159.597   Durbin-Watson:                   1.718
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5777.459
# Skew:                          -2.423   Prob(JB):                         0.00
# Kurtosis:                      28.424   Cond. No.                     1.36e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 1.31e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# **Productivity Transmission Channel**

# %% [markdown]
# **Output per worker**

# %%
model4 = smf.ols(
    "output_per_worker_growth ~ prod_shock + C(sector) + C(year)",
    data=reg_df
).fit(cov_type="HC1")

model4.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 33, but rank is 32
#   warnings.warn('covariance of constraints does not have full '
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ====================================================================================
# Dep. Variable:     output_per_worker_growth   R-squared:                       1.000
# Model:                                  OLS   Adj. R-squared:                  1.000
# Method:                       Least Squares   F-statistic:                 3.935e+29
# Date:                      Mon, 12 Jan 2026   Prob (F-statistic):               0.00
# Time:                              13:27:36   Log-Likelihood:                 6983.6
# No. Observations:                       207   AIC:                        -1.390e+04
# Df Residuals:                           174   BIC:                        -1.379e+04
# Df Model:                                32
# Covariance Type:                        HC1
# ============================================================================================================================================================================
#                                                                                                                coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                   -0.3985    2.7e-16  -1.47e+15      0.000      -0.399      -0.399
# C(sector)[T.Chemicals and chemical products]                                                             -9.492e-17   3.01e-16     -0.316      0.752   -6.85e-16    4.95e-16
# C(sector)[T.Coke, refined petroleum products and nuclear fuel]                                            7.725e-19   3.26e-16      0.002      0.998   -6.38e-16     6.4e-16
# C(sector)[T.Electrical machinery and apparatus n.e.c.]                                                    3.994e-16    4.4e-16      0.907      0.364   -4.63e-16    1.26e-15
# C(sector)[T.Electricity]                                                                                 -2.298e-16   2.77e-16     -0.828      0.408   -7.74e-16    3.14e-16
# C(sector)[T.Fabricated metal products, except machinery and equipment]                                    1.086e-16   3.55e-16      0.306      0.760   -5.88e-16    8.05e-16
# C(sector)[T.Food products and beverages]                                                                  -4.16e-16   2.55e-16     -1.634      0.102   -9.15e-16    8.29e-17
# C(sector)[T.Furniture manufacturing n.e.c.]                                                              -2.042e-16   2.78e-16     -0.733      0.463    -7.5e-16    3.41e-16
# C(sector)[T.General Index]                                                                               -4.978e-17   3.12e-16     -0.159      0.873   -6.62e-16    5.62e-16
# C(sector)[T.Luggage, handbags, saddlery, harness and footwear tanning and dressing of leather products]  -2.904e-16   2.68e-16     -1.085      0.278   -8.15e-16    2.34e-16
# C(sector)[T.Machinery and equipment n.e.c.]                                                               1.221e-16   3.55e-16      0.343      0.731   -5.75e-16    8.19e-16
# C(sector)[T.Manufacturing]                                                                                2.405e-16   3.89e-16      0.618      0.537   -5.23e-16       1e-15
# C(sector)[T.Medical, precision and optical instruments, watches and clocks]                              -1.311e-17   3.26e-16     -0.040      0.968   -6.52e-16    6.26e-16
# C(sector)[T.Mining and Quarrying]                                                                        -6.574e-17   3.11e-16     -0.211      0.833   -6.76e-16    5.45e-16
# C(sector)[T.Motor vehicles, trailers and semi-trailers]                                                    -2.7e-16   2.68e-16     -1.006      0.314   -7.96e-16    2.56e-16
# C(sector)[T.Office, accounting and computing machinery]                                                  -3.506e-17   3.14e-16     -0.112      0.911    -6.5e-16     5.8e-16
# C(sector)[T.Other non-metallic mineral products]                                                          1.166e-18   3.26e-16      0.004      0.997   -6.38e-16     6.4e-16
# C(sector)[T.Other transport equipment]                                                                   -1.841e-16   2.87e-16     -0.642      0.521   -7.47e-16    3.78e-16
# C(sector)[T.Paper and paper products]                                                                    -2.158e-16   2.77e-16     -0.778      0.437    -7.6e-16    3.28e-16
# C(sector)[T.Publishing, printing and reproduction of recorded media]                                     -9.506e-17   3.01e-16     -0.316      0.752   -6.85e-16    4.95e-16
# C(sector)[T.Radio, TV and communication equipment and apparatus]                                         -1.111e-16      3e-16     -0.371      0.711   -6.98e-16    4.76e-16
# C(sector)[T.Rubber and plastics products]                                                                -6.006e-17   3.12e-16     -0.192      0.847   -6.72e-16    5.52e-16
# C(sector)[T.Textiles]                                                                                    -1.007e-16      3e-16     -0.336      0.737   -6.88e-16    4.87e-16
# C(sector)[T.Tobacco products]                                                                            -2.835e-17   3.15e-16     -0.090      0.928   -6.45e-16    5.88e-16
# C(sector)[T.Wearing apparel dressing and dyeing of fur]                                                  -3.547e-17   3.12e-16     -0.114      0.910   -6.48e-16    5.77e-16
# C(sector)[T.Wood and products of wood and cork except furniture articles of straw and plating materials]  -4.51e-17   3.13e-16     -0.144      0.886   -6.59e-16    5.69e-16
# C(year)[T.2006]                                                                                              0.4700   1.58e-16   2.97e+15      0.000       0.470       0.470
# C(year)[T.2007]                                                                                              0.4667   1.98e-16   2.35e+15      0.000       0.467       0.467
# C(year)[T.2008]                                                                                              0.2123   6.93e-17   3.06e+15      0.000       0.212       0.212
# C(year)[T.2009]                                                                                              0.4691   1.69e-16   2.78e+15      0.000       0.469       0.469
# C(year)[T.2010]                                                                                              0.4744   1.83e-16   2.59e+15      0.000       0.474       0.474
# C(year)[T.2011]                                                                                              0.4401   1.85e-16   2.38e+15      0.000       0.440       0.440
# C(year)[T.2012]                                                                                              0.4431   1.35e-16   3.27e+15      0.000       0.443       0.443
# prod_shock                                                                                                   0.2123   6.93e-17   3.06e+15      0.000       0.212       0.212
# ==============================================================================
# Omnibus:                        0.051   Durbin-Watson:                   0.308
# Prob(Omnibus):                  0.975   Jarque-Bera (JB):                0.013
# Skew:                          -0.018   Prob(JB):                        0.993
# Kurtosis:                       2.987   Cond. No.                     1.36e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 1.31e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# **Output per hour**

# %%
model5 = smf.ols(
    "output_per_hour_growth ~ prod_shock + C(sector) + C(year)",
    data=reg_df
).fit(cov_type="HC1")

model5.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 33, but rank is 32
#   warnings.warn('covariance of constraints does not have full '
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:
# C(sector)[T.Radio, TV and communication equipment and apparatus]                                         -8.069e-17   3.04e-16     -0.265      0.791   -6.77e-16    5.16e-16
# C(sector)[T.Rubber and plastics products]                                                                 -5.52e-17   3.04e-16     -0.181      0.856   -6.52e-16    5.42e-16
# C(sector)[T.Textiles]                                                                                    -7.877e-17   3.04e-16     -0.259      0.796   -6.75e-16    5.17e-16
# C(sector)[T.Tobacco products]                                                                            -2.139e-17   3.15e-16     -0.068      0.946    -6.4e-16    5.97e-16
# C(sector)[T.Wearing apparel dressing and dyeing of fur]                                                  -2.594e-17   3.18e-16     -0.082      0.935   -6.49e-16    5.97e-16
# C(sector)[T.Wood and products of wood and cork except furniture articles of straw and plating materials] -5.551e-17   3.04e-16     -0.182      0.855   -6.52e-16    5.41e-16
# C(year)[T.2006]                                                                                              0.4337   1.37e-16   3.16e+15      0.000       0.434       0.434
# C(year)[T.2007]                                                                                              0.4248   1.49e-16   2.84e+15      0.000       0.425       0.425
# C(year)[T.2008]                                                                                              0.1895   4.84e-17   3.91e+15      0.000       0.189       0.189
# C(year)[T.2009]                                                                                              0.4218   1.32e-16    3.2e+15      0.000       0.422       0.422
# C(year)[T.2010]                                                                                              0.4339   1.66e-16   2.61e+15      0.000       0.434       0.434
# C(year)[T.2011]                                                                                              0.3981   1.53e-16    2.6e+15      0.000       0.398       0.398
# C(year)[T.2012]                                                                                              0.3984   1.37e-16    2.9e+15      0.000       0.398       0.398
# prod_shock                                                                                                   0.1895   4.84e-17   3.91e+15      0.000       0.189       0.189
# ==============================================================================
# Omnibus:                        0.969   Durbin-Watson:                   0.166
# Prob(Omnibus):                  0.616   Jarque-Bera (JB):                0.683
# Skew:                           0.117   Prob(JB):                        0.711
# Kurtosis:                       3.156   Cond. No.                     1.36e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 1.31e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# **Lagged Shock Effects (Persistence Test)**

# %%
df["prod_shock_lag1"] = df.groupby("sector")["prod_shock"].shift(1)

lag_df = df.dropna(subset=["sector_output_growth", "prod_shock_lag1"])

model6 = smf.ols(
    "sector_output_growth ~ prod_shock + prod_shock_lag1 + C(sector) + C(year)",
    data=lag_df
).fit(cov_type="HC1")

model6.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 33, but rank is 31
#   warnings.warn('covariance of constraints does not have full '
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     sector_output_growth   R-squared:                       0.338
# Model:                              OLS   Adj. R-squared:                  0.202
# Method:                   Least Squares   F-statistic:                     2.590
# Date:                  Mon, 12 Jan 2026   Prob (F-statistic):           7.19e-05
# Time:                          13:27:45   Log-Likelihood:                 141.90
# No. Observations:                   182   AIC:                            -219.8
# Df Residuals:                       150   BIC:                            -117.3
# Df Model:                            31
# Covariance Type:                    HC1
# ============================================================================================================================================================================
#                                                                                                                coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                
# C(year)[T.2011]                                                                                             -0.1061      0.036     -2.972      0.003      -0.176      -0.036
# C(year)[T.2012]                                                                                             -0.1395      0.030     -4.578      0.000      -0.199      -0.080
# prod_shock                                                                                                  -0.0599      0.016     -3.826      0.000      -0.091      -0.029
# prod_shock_lag1                                                                                             -0.0462      0.017     -2.714      0.007      -0.080      -0.013
# ==============================================================================
# Omnibus:                      133.250   Durbin-Watson:                   1.626
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2416.901
# Skew:                           2.412   Prob(JB):                         0.00
# Kurtosis:                      20.188   Cond. No.                     8.67e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 2.92e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# **Sector Heterogeneity**

# %%
model7 = smf.ols(
    "sector_output_growth ~ prod_shock * C(sector) + C(year)",
    data=reg_df
).fit(cov_type="HC1")

model7.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 58, but rank is 32
#   warnings.warn('covariance of constraints does not have full '
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     sector_output_growth   R-squared:                       0.571
# Model:                              OLS   Adj. R-squared:                  0.407
# Method:                   Least Squares   F-statistic:                     6.183
# Date:                  Mon, 12 Jan 2026   Prob (F-statistic):           4.94e-15
# Time:                          13:28:00   Log-Likelihood:                 66.954
# No. Observations:                   207   AIC:                            -17.91
# Df Residuals:                       149   BIC:                             175.4
# Df Model:                            57
# Covariance Type:                    HC1
# =======================================================================================================================================================================================
#                                                                                                                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                              -0.4601      0.092     -5.002      0.000      -0.640      -0.280
# C(sector)[T.Chemicals and chemical products]                                                                           -0.0646      0.034     -1.926      0.054      -0.130       0.001
# C(sector)[T.Coke, refined petroleum products and nuclear fuel]                                                         -0.0018      0.049     -0.037      0.970      -0.099       0.095
# C(sector)[T.Electrical machinery and apparatus n.e.c.]                                                                  0.0846      0.166      0.509      0.611      -0.241       0.410
# C(sector)[T.Electricity]                                                                                               -0.1349      0.119     -1.132      0.258      -0.368       0.099
# C(sector)[T.Fabricated metal products, except machinery and equipment]                                                  0.0243      0.034      0.709      0.478      -0.043       0.091
# C(sector)[T.Food products and beverages]                                                                               -0.0141      0.030     -0.470      0.638      -0.073       0.045
# C(sector)[T.Furniture manufacturing n.e.c.]                                                                            -0.0537      0.044     -1.229      0.219      -0.139       0.032
# C(sector)[T.General Index]                                                                                              0.0278      0.046      0.607      0.544      -0.062       0.118
# C(sector)[T.Luggage, handbags, saddlery, harness and footwear tanning and dressing of leather products]                -0.0432      0.036     -1.214      0.225      -0.113       0.026
# C(sector)[T.Machinery and equipment n.e.c.]                                                                             0.0887      0.076      1.163      0.245      -0.061       0.238
# C(sector)[T.Manufacturing]                                                                                             -0.0431      0.044     -0.974      0.330      -0.130       0.044
# C(sector)[T.Medical, precision and optical instruments, watches and clocks]                                            -0.0816      0.045     -1.816      0.069      -0.170       0.006
# C(sector)[T.Mining and Quarrying]                                                                                      -0.0010      0.063     -0.016      0.988      -0.124       0.122
# C(sector)[T.Motor vehicles, trailers and semi-trailers]                                                                 0.1013      0.062      1.638      0.102      -0.020       0.222
# C(sector)[T.Office, accounting and computing machinery]                                                                -0.0852      0.028     -3.079      0.002      -0.139      -0.031
# prod_shock:C(sector)[T.Manufacturing]                                                                                   0.0504      0.044      1.137      0.256      -0.036       0.137
# prod_shock:C(sector)[T.Medical, precision and optical instruments, watches and clocks]                                  0.1372      0.045      3.051      0.002       0.049       0.225
# prod_shock:C(sector)[T.Mining and Quarrying]                                                                            0.0093      0.063      0.149      0.882      -0.113       0.132
# prod_shock:C(sector)[T.Motor vehicles, trailers and semi-trailers]                                                     -0.2097      0.062     -3.392      0.001      -0.331      -0.089
# prod_shock:C(sector)[T.Office, accounting and computing machinery]                                                     -0.0341      0.028     -1.233      0.218      -0.088       0.020
# prod_shock:C(sector)[T.Other non-metallic mineral products]                                                            -0.0061      0.052     -0.117      0.907      -0.107       0.095
# prod_shock:C(sector)[T.Other transport equipment]                                                                      -0.0204      0.054     -0.374      0.708      -0.127       0.086
# prod_shock:C(sector)[T.Paper and paper products]                                                                        0.1194      0.052      2.283      0.022       0.017       0.222
# prod_shock:C(sector)[T.Publishing, printing and reproduction of recorded media]                                        -0.0317      0.063     -0.503      0.615      -0.155       0.092
# prod_shock:C(sector)[T.Radio, TV and communication equipment and apparatus]                                            -0.0421      0.128     -0.327      0.743      -0.294       0.210
# prod_shock:C(sector)[T.Rubber and plastics products]                                                                    0.2884      0.261      1.106      0.269      -0.223       0.799
# prod_shock:C(sector)[T.Textiles]                                                                                       -0.0141      0.027     -0.524      0.601      -0.067       0.039
# prod_shock:C(sector)[T.Tobacco products]                                                                                0.0765      0.045      1.687      0.092      -0.012       0.165
# prod_shock:C(sector)[T.Wearing apparel dressing and dyeing of fur]                                                     -0.1721      0.087     -1.972      0.049      -0.343      -0.001
# prod_shock:C(sector)[T.Wood and products of wood and cork except furniture articles of straw and plating materials]     0.0409      0.039      1.038      0.299      -0.036       0.118
# ==============================================================================
# Omnibus:                      156.056   Durbin-Watson:                   1.788
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5955.663
# Skew:                          -2.316   Prob(JB):                         0.00
# Kurtosis:                      28.866   Cond. No.                     1.51e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The smallest eigenvalue is 1.06e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# **Compare Coefficients**

# %%
results = pd.DataFrame({
    "Model": [
        "Baseline",
        "Sector FE",
        "Sector + Time FE",
        "OPW Growth",
        "OPH Growth"
    ],
    "Shock Coefficient": [
        model1.params["prod_shock"],
        model2.params["prod_shock"],
        model3.params["prod_shock"],
        model4.params["prod_shock"],
        model5.params["prod_shock"]
    ],
    "p-value": [
        model1.pvalues["prod_shock"],
        model2.pvalues["prod_shock"],
        model3.pvalues["prod_shock"],
        model4.pvalues["prod_shock"],
        model5.pvalues["prod_shock"]
    ]
})

results
# Out:
#               Model  Shock Coefficient       p-value
# 0          Baseline           0.021605  4.396645e-01
# 1         Sector FE           0.021199  4.829316e-01
# 2  Sector + Time FE           0.245753  2.609264e-08
# 3        OPW Growth           0.212308  0.000000e+00
# 4        OPH Growth           0.189477  0.000000e+00

# %%
import os

# Create the directory if it does not exist
os.makedirs("../outputs", exist_ok=True)

results.to_csv("../outputs/regression_summary.csv", index=False)
